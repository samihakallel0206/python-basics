# %% [markdown]
# <a href="https://colab.research.google.com/github/samihakallel0206/python-basics/blob/main/python_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

print("Welcome to the Guess the Number game!")
print("I'm thinking of a number between 1 and 100. Can you guess what it is?")

secret_number = random.randint(1, 100)

while True:
    guess = input("Enter your guess: ")
    guess = int(guess)

    if guess < secret_number:
        print("Your guess is too low. Guess again.")
    elif guess > secret_number:
        print("Your guess is too high. Guess again.")
    else:
        print("Congratulations! You guessed the number correctly!")
        break
# Out:
# Welcome to the Guess the Number game!
# I'm thinking of a number between 1 and 100. Can you guess what it is?
# Enter your guess: 25
# Your guess is too low. Guess again.
# Enter your guess: 70
# Your guess is too high. Guess again.
# Enter your guess: 50
# Your guess is too low. Guess again.
# Enter your guess: 55
# Your guess is too low. Guess again.
# Enter your guess: 65
# Your guess is too high. Guess again.
# Enter your guess: 60
# Your guess is too high. Guess again.
# Enter your guess: 58
# Your guess is too low. Guess again.
# Enter your guess: 59
# Congratulations! You guessed the number correctly!
